# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import shapiro, chi2_contingency, pearsonr
from scipy.stats import chi2_contingency, f_oneway, kruskal
import os, sys
import warnings
warnings.filterwarnings('ignore')
import sys
import os
# Add project root to PYTHONPATH
sys.path.append(os.path.abspath(".."))
# Corrected
from src.dataset import DatasetProcessor
from src.plots import univariate_analysis_numerical, univariate_analysis_categorical, bivariate_num_vs_num, bivariate_num_vs_cat, bivariate_cat_vs_cat, multivariate_analysis

# %%
df = pd.read_csv('/home/chetanpatil/Documents/food-delivery-time-prediction/data/raw/Food_Delivery_Data.csv')

# %%
# Initialize the processor
processor = DatasetProcessor()

# Clean the data (fit and transform)
df_fe = processor.fit_transform(df)
# Out:
# 2025-11-09 21:51:25,722 INFO - Fitting DatasetProcessor on training data...
# 2025-11-09 21:51:37,832 INFO - Fitted iterative imputer on numeric columns: ['Delivery_person_Age', 'Delivery_person_Ratings', 'multiple_deliveries']
# 2025-11-09 21:51:37,958 INFO - Fitted iterative imputer on coordinate columns: ['Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude']
# 2025-11-09 21:51:37,971 INFO - Learned categorical distribution for City: 3 values
# 2025-11-09 21:51:37,984 INFO - Learned categorical distribution for Weatherconditions: 6 values
# 2025-11-09 21:51:37,997 INFO - Learned categorical distribution for Road_traffic_density: 4 values
# 2025-11-09 21:51:38,012 INFO - Learned categorical distribution for Festival: 2 values
# 2025-11-09 21:51:38,028 INFO - Learned categorical distribution for Type_of_order: 4 values
# 2025-11-09 21:51:38,044 INFO - Learned categorical distribution for Type_of_vehicle: 4 values
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       2 processor = DatasetProcessor()
#       4 # Clean the data (fit and transform)
# ----> 5 df_fe = processor.fit_transform(df)
#
# File ~/miniconda3/envs/aiml-env/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/Documents/food-delivery-time-prediction/src/dataset.py:337, in DatasetProcessor.fit_transform(self, X, y)
#     336 def fit_transform(self, X: pd.DataFrame, y: Optional[pd.Series] = None) -> pd.DataFrame:
# --> 337     return self.fit(X, y).transform(X)
#
# File ~/miniconda3/envs/aiml-env/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/Documents/food-delivery-time-prediction/src/dataset.py:324, in DatasetProcessor.transform(self, X)
#     322     except Exception:
#     323         mode_label = labels[1]  # Morning as safe fallback
# --> 324     df['Order_Time_Category'] = df['Order_Time_Category'].cat.add_categories([mode_label]).fillna(mode_label)
#     326 # drop helper columns to keep output tidy
#     327 df.drop(columns=['Order_Placed', 'Order_Hour', 'Order_Minute'], inplace=True, errors='ignore')
#
# File ~/miniconda3/envs/aiml-env/lib/python3.11/site-packages/pandas/core/accessor.py:112, in PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f(self, *args, **kwargs)
#     111 def f(self, *args, **kwargs):
# --> 112     return self._delegate_method(name, *args, **kwargs)
#
# File ~/miniconda3/envs/aiml-env/lib/python3.11/site-packages/pandas/core/arrays/categorical.py:2982, in CategoricalAccessor._delegate_method(self, name, *args, **kwargs)
#    2979 from pandas import Series
#    2981 method = getattr(self._parent, name)
# -> 2982 res = method(*args, **kwargs)
#    2983 if res is not None:
#    2984     return Series(res, index=self._index, name=self._name)
#
# File ~/miniconda3/envs/aiml-env/lib/python3.11/site-packages/pandas/core/arrays/categorical.py:1331, in Categorical.add_categories(self, new_categories)
#    1329 already_included = set(new_categories) & set(self.dtype.categories)
#    1330 if len(already_included) != 0:
# -> 1331     raise ValueError(
#    1332         f"new categories must not include old categories: {already_included}"
#    1333     )
#    1335 if hasattr(new_categories, "dtype"):
#    1336     from pandas import Series
#
# ValueError: new categories must not include old categories: {'Evening'}

# %%
df_clean.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                 37.0                      4.9
# 1  0xb379     BANGRES18DEL02                 34.0                      4.5
# 2  0x5d6d     BANGRES19DEL01                 23.0                      4.4
# 3  0x7a6a    COIMBRES13DEL02                 38.0                      4.7
# 4  0x70a2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    75.912471  2022-03-19    11:30:00          11:45:00
# 1                    77.813237  2022-03-25    19:45:00          19:50:00
# 2                    77.688400  2022-03-19    08:30:00          08:45:00
# 3                    77.026494  2022-04-05    18:00:00          18:10:00
# 4                    80.289982  2022-03-26    13:30:00          13:45:00
#
#   Weatherconditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0             Sunny                 High                  2         Snack
# 1            Stormy                  Jam                  2         Snack
# 2        Sandstorms                  Low                  0        Drinks
# 3             Sunny               Medium                  0        Buffet
# 4            Cloudy                 High                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      Motorcycle                  0.0       No          Urban
# 1         Scooter                  1.0       No  Metropolitian
# 2      Motorcycle                  1.0       No          Urban
# 3      Motorcycle                  1.0       No  Metropolitian
# 4         Scooter                  1.0       No  Metropolitian
#
#    Time_taken(min)
# 0               24
# 1               33
# 2               26
# 3               21
# 4               30

# %%
# Separate numerical and categorical columns
num_cols = df_clean.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = df_clean.select_dtypes(exclude=[np.number]).columns.tolist()

print("\nNumerical Columns:\n", num_cols)
print("\nCategorical Columns:\n", cat_cols)

# %%
univariate_analysis_numerical(df_clean,'Time_taken(min)')

# %%
univariate_analysis_numerical(df_clean,'Delivery_person_Age')

# %%
univariate_analysis_numerical(df_clean,'Delivery_person_Ratings')

# %%
univariate_analysis_numerical(df_clean,'Restaurant_latitude')

# %%
univariate_analysis_numerical(df_clean,'Restaurant_longitude')

# %%
univariate_analysis_numerical(df_clean,'Delivery_location_latitude')

# %%
univariate_analysis_numerical(df_clean,'Delivery_location_longitude')

# %%
univariate_analysis_numerical(df_clean,'Vehicle_condition')

# %%
univariate_analysis_numerical(df_clean,'multiple_deliveries')

# %%
univariate_analysis_categorical(df_clean,'Weatherconditions')

# %%
univariate_analysis_categorical(df_clean,'Road_traffic_density')

# %%
univariate_analysis_categorical(df_clean,'Type_of_order')

# %%
univariate_analysis_categorical(df_clean,'Type_of_vehicle')

# %%
univariate_analysis_categorical(df_clean,'Festival')

# %%
univariate_analysis_categorical(df_clean,'City')

# %%
bivariate_num_vs_cat(df_clean,'Time_taken(min)','Weatherconditions')

# %%
bivariate_num_vs_cat(df_clean,'Time_taken(min)','Road_traffic_density')

# %%
bivariate_num_vs_cat(df_clean,'Time_taken(min)','Type_of_order')

# %%
bivariate_num_vs_cat(df_clean,'Time_taken(min)','Type_of_vehicle')

# %%
bivariate_num_vs_cat(df_clean,'Time_taken(min)','Festival')

# %%
bivariate_num_vs_cat(df_clean,'Time_taken(min)','City')

# %%
bivariate_num_vs_num(df_clean,'Time_taken(min)','Delivery_person_Age')

# %%
bivariate_num_vs_num(df_clean,'Time_taken(min)','Delivery_person_Age')

# %%
bivariate_num_vs_num(df_clean,'Time_taken(min)','Delivery_person_Ratings')

# %%
bivariate_num_vs_num(df_clean,'Time_taken(min)','Restaurant_latitude')

# %%
bivariate_num_vs_num(df_clean,'Time_taken(min)','Restaurant_longitude')

# %%
bivariate_num_vs_num(df_clean,'Time_taken(min)','Delivery_location_latitude')

# %%
bivariate_num_vs_num(df_clean,'Time_taken(min)','Delivery_location_longitude')

# %%
bivariate_num_vs_num(df_clean,'Time_taken(min)','Vehicle_condition')

# %%
bivariate_num_vs_num(df_clean,'Time_taken(min)','multiple_deliveries')

# %%
bivariate_cat_vs_cat(df_clean,'Weatherconditions','Road_traffic_density')

# %%
bivariate_cat_vs_cat(df_clean,'Type_of_order','Type_of_vehicle')

# %%
bivariate_cat_vs_cat(df_clean,'Festival','Road_traffic_density')

# %%
bivariate_cat_vs_cat(df_clean,'City','Road_traffic_density')

# %%
bivariate_cat_vs_cat(df_clean,'Weatherconditions','City')

# %%
bivariate_cat_vs_cat(df_clean,'Festival','Type_of_order')

# %%
multivariate_analysis(df_clean, num_cols)
